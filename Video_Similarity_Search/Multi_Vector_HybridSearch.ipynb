# %% [markdown]
# # Cell 1: Cấu hình và import

# %%
import os
import json
import pandas as pd
from PIL import Image
import torch
import psycopg2
from transformers import CLIPModel, CLIPProcessor
from llama_index.vector_stores.milvus import MilvusVectorStore
from llama_index.core import StorageContext
from llama_index.vector_stores.milvus.utils import BM25BuiltInFunction
from deep_translator import GoogleTranslator
import torch.nn.functional as F
from pydantic import ConfigDict
from llama_index.core.embeddings import BaseEmbedding
from pymilvus import MilvusClient, DataType

# Config
DB_PARAMS = {
    "dbname": "video_hybrid_csv",  # Updated database name
    "user": "postgres",
    "password": "123",
    "host": "localhost",
    "port": "5432"
}

JSON_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\media-info"
VIDEO_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\video"
FRAME_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes"
CSV_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\csv"
MODEL_DIR = r"D:\Big_project_2025\huggingface_cache"

URI = "http://localhost:19530"
COLLECTION_NAME = "video_hybrid_search"

# %% [markdown]
# # Cell 2: Khởi tạo CLIP và Custom Embedding

# %%
# Initialize CLIP Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR).to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32", cache_dir=MODEL_DIR)

# Custom CLIP Embedding class
class CustomCLIPEmbedding(BaseEmbedding):
    model_config = ConfigDict(arbitrary_types_allowed=True, extra="allow")

    def __init__(self, model, processor, device):
        super().__init__()
        self.model = model
        self.processor = processor
        self.device = device

    def _get_text_embedding(self, text: str) -> list:
        inputs = self.processor(text=[text], return_tensors="pt", padding=True, truncation=True, max_length=77).to(self.device)
        with torch.no_grad():
            text_features = self.model.get_text_features(**inputs)
        return F.normalize(text_features, p=2, dim=1)[0].cpu().numpy().tolist()

    def _get_query_embedding(self, query: str) -> list:
        return self._get_text_embedding(query)

    async def _aget_query_embedding(self, query: str) -> list:
        return self._get_text_embedding(query)

    def _get_text_embeddings(self, texts: list) -> list:
        inputs = self.processor(text=texts, return_tensors="pt", padding=True, truncation=True, max_length=77).to(self.device)
        with torch.no_grad():
            text_features = self.model.get_text_features(**inputs)
        return F.normalize(text_features, p=2, dim=1).cpu().numpy().tolist()

# Initialize custom embedding
clip_embedding = CustomCLIPEmbedding(model, processor, device)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %% [markdown]
# # Cell 3: Khởi tạo Milvus và PostgreSQL

# %%
# Initialize Milvus
bm25_function = BM25BuiltInFunction(
    analyzer_params={
        "tokenizer": "standard",
        "filter": [
            "lowercase",
            {"type": "length", "max": 40},
            {"type": "stop", "stop_words": ["of", "to", "and"]}
        ],
    },
    enable_match=True,
)
milvus_client = MilvusClient(uri=URI)
vector_store = MilvusVectorStore(
    uri=URI,
    collection_name=COLLECTION_NAME,
    dim=512,
    enable_sparse=True,
    sparse_embedding_function=bm25_function,
    hybrid_ranker="RRFRanker",
    hybrid_ranker_params={"k": 60},
    similarity_metric="IP",
    index_config={"index_type": "HNSW", "metric_type": "IP", "params": {"M": 16, "efConstruction": 200}},
    sparse_index_config={"index_type": "SPARSE_INVERTED_INDEX", "metric_type": "IP"},
    overwrite=True,
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Initialize PostgreSQL
conn = psycopg2.connect(**DB_PARAMS)
cur = conn.cursor()
cur.execute("""
    CREATE TABLE IF NOT EXISTS videos (
        id SERIAL PRIMARY KEY,
        video_path TEXT UNIQUE,
        title TEXT,
        description TEXT
    );
    CREATE TABLE IF NOT EXISTS frame_mappings (
        id SERIAL PRIMARY KEY,
        video_id INTEGER REFERENCES videos(id),
        frame_path TEXT UNIQUE,
        pts_time FLOAT,
        frame_idx INTEGER,
        fps FLOAT,
        milvus_id TEXT
    );
""")
conn.commit()

# %% [markdown]
# # Cell 4: Helper Functions

# %%
def encode_image(image_path):
    try:
        image = Image.open(image_path)
        inputs = processor(images=image, return_tensors="pt").to(device)
        with torch.no_grad():
            image_features = model.get_image_features(**inputs)
        return image_features[0].cpu().numpy()
    except Exception as e:
        print(f"Error encoding {image_path}: {e}")
        return None

def encode_images_batch(image_paths):
    try:
        images = [Image.open(path) for path in image_paths]
        inputs = processor(images=images, return_tensors="pt").to(device)
        with torch.no_grad():
            image_features = model.get_image_features(**inputs)
        return image_features.cpu().numpy()
    except Exception as e:
        print(f"Error encoding batch {image_paths}: {e}")
        return None

def time_to_seconds(time_str):
    try:
        minutes, seconds = map(int, time_str.split(':'))
        return minutes * 60 + seconds
    except ValueError:
        print(f"Invalid time format: {time_str}")
        return None

def format_time(seconds):
    m = int(seconds // 60)
    s = int(seconds % 60)
    return f"{m}:{s:02d}"

def group_timestamps(timestamps, gap_threshold=15.0):
    if not timestamps:
        return []
    timestamps = sorted(timestamps)
    ranges = []
    start = timestamps[0]
    end = timestamps[0]
    for t in timestamps[1:]:
        if t - end <= gap_threshold:
            end = t
        else:
            ranges.append((start, end))
            start = t
            end = t
    ranges.append((start, end))
    return ranges

def keyframe_path_from_frame_idx(video_path, frame_idx, csv_dir, frame_root):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    csv_path = os.path.join(csv_dir, f"{video_name}.csv")
    dir_path = os.path.join(frame_root, video_name)
    
    if not os.path.exists(csv_path):
        return None
    try:
        df = pd.read_csv(csv_path)
        if not all(c in df.columns for c in ["n", "frame_idx"]):
            return None
        idx = (df["frame_idx"] - int(frame_idx)).abs().idxmin()
        n_val = int(df.loc[idx, "n"])
        candidates = [os.path.join(dir_path, f"{stem}.{ext}") 
                     for stem in [n_val, f"{n_val:03d}", f"{n_val:04d}", frame_idx, f"{int(frame_idx):03d}", f"{int(frame_idx):04d}"]
                     for ext in ("jpg", "jpeg", "png")]
        for p in candidates:
            if os.path.exists(p):
                return p
    except Exception:
        return None
    return None

def get_frame_idx_from_time(video_path, time_start, time_end, csv_dir):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    csv_path = os.path.join(csv_dir, f"{video_name}.csv")
    
    if not os.path.exists(csv_path):
        print(f"CSV not found: {csv_path}")
        return None
    
    try:
        df = pd.read_csv(csv_path)
        if not all(col in df.columns for col in ['pts_time', 'frame_idx', 'fps']):
            print(f"CSV {csv_path} missing required columns")
            return None
    except Exception as e:
        print(f"Error reading CSV {csv_path}: {e}")
        return None
    
    start_sec = time_to_seconds(time_start)
    end_sec = time_to_seconds(time_end)
    if start_sec is None or end_sec is None:
        return None
    
    target_time = (start_sec + end_sec) / 2
    df['time_diff'] = abs(df['pts_time'] - target_time)
    closest_row = df.loc[df['time_diff'].idxmin()]
    return int(closest_row['frame_idx'])

# %% [markdown]
# # Cell 5: Indexing Pipeline

# %%
import os, json
import pandas as pd
from PIL import Image
from pymilvus import connections, utility, Collection, FieldSchema, CollectionSchema, DataType

# Biến toàn cục
COLLECTION_NAME = "video_hybrid_search"
FRAME_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes"
CSV_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\csv"
VIDEO_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\video"
JSON_DIR = r"D:\Big_project_2025\Video_Similarity_Search\data_hybrid\media-info"

# Hàm insert vào Milvus
def insert_to_milvus(collection, data):
    try:
        collection.insert([data])
        print(f"✅ Inserted {data['id']} into Milvus")
        return data["id"]
    except Exception as e:
        print(f"❌ Milvus insert error for {data.get('frame_path', '')}: {e}")
        return None

# Hàm insert vào PostgreSQL
def insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id):
    try:
        cur.execute("""
            INSERT INTO frame_mappings (video_id, frame_path, pts_time, frame_idx, fps, milvus_id)
            VALUES (%s, %s, %s, %s, %s, %s)
            ON CONFLICT (frame_path) DO NOTHING
        """, (video_id, frame_path, pts_time, frame_idx, fps, milvus_id))
        print(f"✅ Inserted {frame_path} into Postgres")
    except Exception as e:
        print(f"❌ Postgres insert error: {e}")

# Hàm chính
def index_videos():
    # Kết nối Milvus
    try:
        connections.connect(host='localhost', port=19530)
        print(f"🔍 Milvus version: {utility.get_server_version()}")
    except Exception as e:
        print(f"❌ Milvus connection error: {e}")
        return

    # Tạo collection
    if utility.has_collection(COLLECTION_NAME):
        utility.drop_collection(COLLECTION_NAME)
        print(f"🔧 Dropped existing collection {COLLECTION_NAME}")

    fields = [
        FieldSchema("id", DataType.VARCHAR, max_length=100, is_primary=True, auto_id=False),
        FieldSchema("vector", DataType.FLOAT_VECTOR, dim=512),
        FieldSchema("frame_path", DataType.VARCHAR, max_length=512),
        FieldSchema("video_id", DataType.VARCHAR, max_length=100)
    ]
    schema = CollectionSchema(fields, enable_dynamic_field=True)

    try:
        collection = Collection(COLLECTION_NAME, schema)
        collection.create_index("vector", {
            "index_type": "HNSW", "metric_type": "IP", "params": {"M": 16, "efConstruction": 200}
        })
        collection.load()
        print(f"✅ Collection {COLLECTION_NAME} ready")
    except Exception as e:
        print(f"❌ Collection setup error: {e}")
        return

    # Index metadata
    for json_file in os.listdir(JSON_DIR):
        if not json_file.endswith(".json"):
            continue
        try:
            with open(os.path.join(JSON_DIR, json_file), "r", encoding="utf-8") as f:
                metadata = json.load(f)

            video_name = os.path.splitext(json_file)[0]
            video_path = os.path.join(VIDEO_DIR, f"{video_name}.mp4").replace("\\", "/")
            text_content = "\n".join([
                metadata.get("title", ""),
                metadata.get("description", ""),
                " ".join(metadata.get("keywords", []))
            ])
            dense_emb = clip_embedding._get_text_embedding(text_content)

            insert_to_milvus(collection, {
                "id": video_name,
                "vector": dense_emb,
                "frame_path": "",
                "video_id": video_name
            })

            cur.execute("""
                INSERT INTO videos (video_path, title, description)
                VALUES (%s, %s, %s)
                ON CONFLICT (video_path) DO NOTHING
            """, (video_path, metadata.get("title", ""), metadata.get("description", "")))
            conn.commit()
        except Exception as e:
            print(f"❌ Metadata error in {json_file}: {e}")

    # Index frames
    for key_frame_dir in os.listdir(FRAME_DIR):
        frame_dir = os.path.join(FRAME_DIR, key_frame_dir)
        csv_path = os.path.join(CSV_DIR, f"{key_frame_dir}.csv")
        video_path = os.path.join(VIDEO_DIR, f"{key_frame_dir}.mp4").replace("\\", "/")

        if not (os.path.isdir(frame_dir) and os.path.exists(csv_path) and os.path.exists(video_path)):
            print(f"⚠️ Missing data for {key_frame_dir}, skipping")
            continue

        try:
            df = pd.read_csv(csv_path)
            cur.execute("""
                INSERT INTO videos (video_path, title, description)
                VALUES (%s, %s, %s)
                ON CONFLICT (video_path) DO NOTHING
                RETURNING id
            """, (video_path, os.path.basename(video_path), "Video demo"))
            row = cur.fetchone()
            video_id = row[0] if row else cur.execute("SELECT id FROM videos WHERE video_path=%s", (video_path,)) or cur.fetchone()[0]

            print(f"🎥 Indexing frames for {key_frame_dir} (video_id={video_id})")
            for frame_file in os.listdir(frame_dir):
                if not frame_file.lower().endswith((".jpg", ".jpeg", ".png")):
                    continue
                try:
                    frame_path = os.path.join(frame_dir, frame_file).replace("\\", "/")
                    frame_idx = int(os.path.splitext(frame_file)[0])
                    row = df[df["n"] == frame_idx]
                    if row.empty:
                        continue
                    pts_time = float(row["pts_time"].values[0])
                    fps = int(row["fps"].values[0])
                    emb = encode_image(frame_path)
                    if emb is None:
                        continue
                    milvus_id = insert_to_milvus(collection, {
                        "id": f"frame_{key_frame_dir}_{frame_idx}",
                        "vector": emb.tolist(),
                        "frame_path": frame_path,
                        "video_id": key_frame_dir
                    })
                    if milvus_id:
                        insert_to_postgres(video_id, frame_path, pts_time, frame_idx, fps, milvus_id)
                except Exception as e:
                    print(f"❌ Frame error in {frame_file}: {e}")
            conn.commit()
            print(f"✅ Done indexing {key_frame_dir}")
        except Exception as e:
            print(f"❌ Error processing {key_frame_dir}: {e}")

# Chạy index
index_videos()
# Out:
# 🔍 Milvus version: v2.4.7
# 🔧 Dropped existing collection video_hybrid_search
# ✅ Collection video_hybrid_search ready
# ✅ Inserted L26_V001 into Milvus
# ✅ Inserted L26_V002 into Milvus
# ✅ Inserted L26_V003 into Milvus
# 🎥 Indexing frames for L26_V001 (video_id=1)
# ✅ Inserted frame_L26_V001_1 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/001.jpg into Postgres
# ✅ Inserted frame_L26_V001_2 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/002.jpg into Postgres
# ✅ Inserted frame_L26_V001_3 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/003.jpg into Postgres
# ✅ Inserted frame_L26_V001_4 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/004.jpg into Postgres
# ✅ Inserted frame_L26_V001_5 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/005.jpg into Postgres
# ✅ Inserted frame_L26_V001_6 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/006.jpg into Postgres
# ✅ Inserted frame_L26_V001_7 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/007.jpg into Postgres
# ✅ Inserted frame_L26_V001_8 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/008.jpg into Postgres
# ✅ Inserted frame_L26_V001_9 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/009.jpg into Postgres
# ✅ Inserted frame_L26_V001_10 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/010.jpg into Postgres
# ✅ Inserted frame_L26_V001_11 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/011.jpg into Postgres
# ✅ Inserted frame_L26_V001_12 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/012.jpg into Postgres
# ✅ Inserted frame_L26_V001_13 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/013.jpg into Postgres
# ✅ Inserted frame_L26_V001_14 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/014.jpg into Postgres
# ✅ Inserted frame_L26_V001_15 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/015.jpg into Postgres
# ✅ Inserted frame_L26_V001_16 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/016.jpg into Postgres
# ✅ Inserted frame_L26_V001_17 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/017.jpg into Postgres
# ✅ Inserted frame_L26_V001_18 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/018.jpg into Postgres
# ✅ Inserted frame_L26_V001_19 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/019.jpg into Postgres
# ✅ Inserted frame_L26_V001_20 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/020.jpg into Postgres
# ✅ Inserted frame_L26_V001_21 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/021.jpg into Postgres
# ✅ Inserted frame_L26_V001_22 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/022.jpg into Postgres
# ✅ Inserted frame_L26_V001_23 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/023.jpg into Postgres
# ✅ Inserted frame_L26_V001_24 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/024.jpg into Postgres
# ✅ Inserted frame_L26_V001_25 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/025.jpg into Postgres
# ✅ Inserted frame_L26_V001_26 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/026.jpg into Postgres
# ✅ Inserted frame_L26_V001_27 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/027.jpg into Postgres
# ✅ Inserted frame_L26_V001_28 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/028.jpg into Postgres
# ✅ Inserted frame_L26_V001_29 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/029.jpg into Postgres
# ✅ Inserted frame_L26_V001_30 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/030.jpg into Postgres
# ✅ Inserted frame_L26_V001_31 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/031.jpg into Postgres
# ✅ Inserted frame_L26_V001_32 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/032.jpg into Postgres
# ✅ Inserted frame_L26_V001_33 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/033.jpg into Postgres
# ✅ Inserted frame_L26_V001_34 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/034.jpg into Postgres
# ✅ Inserted frame_L26_V001_35 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/035.jpg into Postgres
# ✅ Inserted frame_L26_V001_36 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/036.jpg into Postgres
# ✅ Inserted frame_L26_V001_37 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/037.jpg into Postgres
# ✅ Inserted frame_L26_V001_38 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/038.jpg into Postgres
# ✅ Inserted frame_L26_V001_39 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/039.jpg into Postgres
# ✅ Inserted frame_L26_V001_40 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/040.jpg into Postgres
# ✅ Inserted frame_L26_V001_41 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/041.jpg into Postgres
# ✅ Inserted frame_L26_V001_42 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/042.jpg into Postgres
# ✅ Inserted frame_L26_V001_43 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/043.jpg into Postgres
# ✅ Inserted frame_L26_V001_44 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/044.jpg into Postgres
# ✅ Inserted frame_L26_V001_45 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/045.jpg into Postgres
# ✅ Inserted frame_L26_V001_46 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/046.jpg into Postgres
# ✅ Inserted frame_L26_V001_47 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/047.jpg into Postgres
# ✅ Inserted frame_L26_V001_48 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/048.jpg into Postgres
# ✅ Inserted frame_L26_V001_49 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/049.jpg into Postgres
# ✅ Inserted frame_L26_V001_50 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/050.jpg into Postgres
# ✅ Inserted frame_L26_V001_51 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/051.jpg into Postgres
# ✅ Inserted frame_L26_V001_52 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/052.jpg into Postgres
# ✅ Inserted frame_L26_V001_53 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/053.jpg into Postgres
# ✅ Inserted frame_L26_V001_54 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/054.jpg into Postgres
# ✅ Inserted frame_L26_V001_55 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/055.jpg into Postgres
# ✅ Inserted frame_L26_V001_56 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/056.jpg into Postgres
# ✅ Inserted frame_L26_V001_57 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/057.jpg into Postgres
# ✅ Inserted frame_L26_V001_58 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/058.jpg into Postgres
# ✅ Inserted frame_L26_V001_59 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/059.jpg into Postgres
# ✅ Inserted frame_L26_V001_60 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/060.jpg into Postgres
# ✅ Inserted frame_L26_V001_61 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/061.jpg into Postgres
# ✅ Inserted frame_L26_V001_62 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/062.jpg into Postgres
# ✅ Inserted frame_L26_V001_63 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/063.jpg into Postgres
# ✅ Inserted frame_L26_V001_64 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/064.jpg into Postgres
# ✅ Inserted frame_L26_V001_65 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/065.jpg into Postgres
# ✅ Inserted frame_L26_V001_66 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/066.jpg into Postgres
# ✅ Inserted frame_L26_V001_67 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/067.jpg into Postgres
# ✅ Inserted frame_L26_V001_68 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/068.jpg into Postgres
# ✅ Inserted frame_L26_V001_69 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/069.jpg into Postgres
# ✅ Inserted frame_L26_V001_70 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/070.jpg into Postgres
# ✅ Inserted frame_L26_V001_71 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/071.jpg into Postgres
# ✅ Inserted frame_L26_V001_72 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/072.jpg into Postgres
# ✅ Inserted frame_L26_V001_73 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/073.jpg into Postgres
# ✅ Inserted frame_L26_V001_74 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/074.jpg into Postgres
# ✅ Inserted frame_L26_V001_75 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/075.jpg into Postgres
# ✅ Inserted frame_L26_V001_76 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/076.jpg into Postgres
# ✅ Inserted frame_L26_V001_77 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/077.jpg into Postgres
# ✅ Inserted frame_L26_V001_78 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/078.jpg into Postgres
# ✅ Inserted frame_L26_V001_79 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/079.jpg into Postgres
# ✅ Inserted frame_L26_V001_80 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/080.jpg into Postgres
# ✅ Inserted frame_L26_V001_81 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/081.jpg into Postgres
# ✅ Inserted frame_L26_V001_82 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/082.jpg into Postgres
# ✅ Inserted frame_L26_V001_83 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/083.jpg into Postgres
# ✅ Inserted frame_L26_V001_84 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/084.jpg into Postgres
# ✅ Inserted frame_L26_V001_85 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/085.jpg into Postgres
# ✅ Inserted frame_L26_V001_86 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/086.jpg into Postgres
# ✅ Inserted frame_L26_V001_87 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/087.jpg into Postgres
# ✅ Inserted frame_L26_V001_88 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/088.jpg into Postgres
# ✅ Inserted frame_L26_V001_89 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/089.jpg into Postgres
# ✅ Inserted frame_L26_V001_90 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/090.jpg into Postgres
# ✅ Inserted frame_L26_V001_91 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/091.jpg into Postgres
# ✅ Inserted frame_L26_V001_92 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/092.jpg into Postgres
# ✅ Inserted frame_L26_V001_93 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/093.jpg into Postgres
# ✅ Inserted frame_L26_V001_94 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/094.jpg into Postgres
# ✅ Inserted frame_L26_V001_95 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/095.jpg into Postgres
# ✅ Inserted frame_L26_V001_96 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/096.jpg into Postgres
# ✅ Inserted frame_L26_V001_97 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/097.jpg into Postgres
# ✅ Inserted frame_L26_V001_98 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/098.jpg into Postgres
# ✅ Inserted frame_L26_V001_99 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/099.jpg into Postgres
# ✅ Inserted frame_L26_V001_100 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/100.jpg into Postgres
# ✅ Inserted frame_L26_V001_101 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/101.jpg into Postgres
# ✅ Inserted frame_L26_V001_102 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/102.jpg into Postgres
# ✅ Inserted frame_L26_V001_103 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/103.jpg into Postgres
# ✅ Inserted frame_L26_V001_104 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/104.jpg into Postgres
# ✅ Inserted frame_L26_V001_105 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/105.jpg into Postgres
# ✅ Inserted frame_L26_V001_106 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/106.jpg into Postgres
# ✅ Inserted frame_L26_V001_107 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/107.jpg into Postgres
# ✅ Inserted frame_L26_V001_108 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/108.jpg into Postgres
# ✅ Inserted frame_L26_V001_109 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/109.jpg into Postgres
# ✅ Inserted frame_L26_V001_110 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/110.jpg into Postgres
# ✅ Inserted frame_L26_V001_111 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/111.jpg into Postgres
# ✅ Inserted frame_L26_V001_112 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/112.jpg into Postgres
# ✅ Inserted frame_L26_V001_113 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/113.jpg into Postgres
# ✅ Inserted frame_L26_V001_114 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/114.jpg into Postgres
# ✅ Inserted frame_L26_V001_115 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/115.jpg into Postgres
# ✅ Inserted frame_L26_V001_116 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/116.jpg into Postgres
# ✅ Inserted frame_L26_V001_117 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/117.jpg into Postgres
# ✅ Inserted frame_L26_V001_118 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/118.jpg into Postgres
# ✅ Inserted frame_L26_V001_119 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/119.jpg into Postgres
# ✅ Inserted frame_L26_V001_120 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/120.jpg into Postgres
# ✅ Inserted frame_L26_V001_121 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/121.jpg into Postgres
# ✅ Inserted frame_L26_V001_122 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/122.jpg into Postgres
# ✅ Inserted frame_L26_V001_123 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/123.jpg into Postgres
# ✅ Inserted frame_L26_V001_124 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/124.jpg into Postgres
# ✅ Inserted frame_L26_V001_125 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/125.jpg into Postgres
# ✅ Done indexing L26_V001
# 🎥 Indexing frames for L26_V002 (video_id=2)
# ✅ Inserted frame_L26_V002_1 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/001.jpg into Postgres
# ✅ Inserted frame_L26_V002_2 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/002.jpg into Postgres
# ✅ Inserted frame_L26_V002_3 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/003.jpg into Postgres
# ✅ Inserted frame_L26_V002_4 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/004.jpg into Postgres
# ✅ Inserted frame_L26_V002_5 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/005.jpg into Postgres
# ✅ Inserted frame_L26_V002_6 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/006.jpg into Postgres
# ✅ Inserted frame_L26_V002_7 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/007.jpg into Postgres
# ✅ Inserted frame_L26_V002_8 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/008.jpg into Postgres
# ✅ Inserted frame_L26_V002_9 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/009.jpg into Postgres
# ✅ Inserted frame_L26_V002_10 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/010.jpg into Postgres
# ✅ Inserted frame_L26_V002_11 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/011.jpg into Postgres
# ✅ Inserted frame_L26_V002_12 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/012.jpg into Postgres
# ✅ Inserted frame_L26_V002_13 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/013.jpg into Postgres
# ✅ Inserted frame_L26_V002_14 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/014.jpg into Postgres
# ✅ Inserted frame_L26_V002_15 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/015.jpg into Postgres
# ✅ Inserted frame_L26_V002_16 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/016.jpg into Postgres
# ✅ Inserted frame_L26_V002_17 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/017.jpg into Postgres
# ✅ Inserted frame_L26_V002_18 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/018.jpg into Postgres
# ✅ Inserted frame_L26_V002_19 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/019.jpg into Postgres
# ✅ Inserted frame_L26_V002_20 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/020.jpg into Postgres
# ✅ Inserted frame_L26_V002_21 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/021.jpg into Postgres
# ✅ Inserted frame_L26_V002_22 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/022.jpg into Postgres
# ✅ Inserted frame_L26_V002_23 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/023.jpg into Postgres
# ✅ Inserted frame_L26_V002_24 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/024.jpg into Postgres
# ✅ Inserted frame_L26_V002_25 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/025.jpg into Postgres
# ✅ Inserted frame_L26_V002_26 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/026.jpg into Postgres
# ✅ Inserted frame_L26_V002_27 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/027.jpg into Postgres
# ✅ Inserted frame_L26_V002_28 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/028.jpg into Postgres
# ✅ Inserted frame_L26_V002_29 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/029.jpg into Postgres
# ✅ Inserted frame_L26_V002_30 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/030.jpg into Postgres
# ✅ Inserted frame_L26_V002_31 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/031.jpg into Postgres
# ✅ Inserted frame_L26_V002_32 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/032.jpg into Postgres
# ✅ Inserted frame_L26_V002_33 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/033.jpg into Postgres
# ✅ Inserted frame_L26_V002_34 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/034.jpg into Postgres
# ✅ Inserted frame_L26_V002_35 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/035.jpg into Postgres
# ✅ Inserted frame_L26_V002_36 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/036.jpg into Postgres
# ✅ Inserted frame_L26_V002_37 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/037.jpg into Postgres
# ✅ Inserted frame_L26_V002_38 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/038.jpg into Postgres
# ✅ Inserted frame_L26_V002_39 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/039.jpg into Postgres
# ✅ Inserted frame_L26_V002_40 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/040.jpg into Postgres
# ✅ Inserted frame_L26_V002_41 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/041.jpg into Postgres
# ✅ Inserted frame_L26_V002_42 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/042.jpg into Postgres
# ✅ Inserted frame_L26_V002_43 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/043.jpg into Postgres
# ✅ Inserted frame_L26_V002_44 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/044.jpg into Postgres
# ✅ Inserted frame_L26_V002_45 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/045.jpg into Postgres
# ✅ Inserted frame_L26_V002_46 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/046.jpg into Postgres
# ✅ Inserted frame_L26_V002_47 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/047.jpg into Postgres
# ✅ Inserted frame_L26_V002_48 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/048.jpg into Postgres
# ✅ Inserted frame_L26_V002_49 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/049.jpg into Postgres
# ✅ Inserted frame_L26_V002_50 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/050.jpg into Postgres
# ✅ Inserted frame_L26_V002_51 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/051.jpg into Postgres
# ✅ Inserted frame_L26_V002_52 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/052.jpg into Postgres
# ✅ Inserted frame_L26_V002_53 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/053.jpg into Postgres
# ✅ Inserted frame_L26_V002_54 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/054.jpg into Postgres
# ✅ Inserted frame_L26_V002_55 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/055.jpg into Postgres
# ✅ Inserted frame_L26_V002_56 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/056.jpg into Postgres
# ✅ Inserted frame_L26_V002_57 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/057.jpg into Postgres
# ✅ Inserted frame_L26_V002_58 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/058.jpg into Postgres
# ✅ Inserted frame_L26_V002_59 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/059.jpg into Postgres
# ✅ Inserted frame_L26_V002_60 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/060.jpg into Postgres
# ✅ Inserted frame_L26_V002_61 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/061.jpg into Postgres
# ✅ Inserted frame_L26_V002_62 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/062.jpg into Postgres
# ✅ Inserted frame_L26_V002_63 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/063.jpg into Postgres
# ✅ Inserted frame_L26_V002_64 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/064.jpg into Postgres
# ✅ Inserted frame_L26_V002_65 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/065.jpg into Postgres
# ✅ Inserted frame_L26_V002_66 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/066.jpg into Postgres
# ✅ Inserted frame_L26_V002_67 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/067.jpg into Postgres
# ✅ Inserted frame_L26_V002_68 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/068.jpg into Postgres
# ✅ Inserted frame_L26_V002_69 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/069.jpg into Postgres
# ✅ Inserted frame_L26_V002_70 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/070.jpg into Postgres
# ✅ Inserted frame_L26_V002_71 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/071.jpg into Postgres
# ✅ Inserted frame_L26_V002_72 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/072.jpg into Postgres
# ✅ Inserted frame_L26_V002_73 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/073.jpg into Postgres
# ✅ Inserted frame_L26_V002_74 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/074.jpg into Postgres
# ✅ Inserted frame_L26_V002_75 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/075.jpg into Postgres
# ✅ Inserted frame_L26_V002_76 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/076.jpg into Postgres
# ✅ Inserted frame_L26_V002_77 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/077.jpg into Postgres
# ✅ Inserted frame_L26_V002_78 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/078.jpg into Postgres
# ✅ Inserted frame_L26_V002_79 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/079.jpg into Postgres
# ✅ Inserted frame_L26_V002_80 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/080.jpg into Postgres
# ✅ Inserted frame_L26_V002_81 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/081.jpg into Postgres
# ✅ Inserted frame_L26_V002_82 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/082.jpg into Postgres
# ✅ Inserted frame_L26_V002_83 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/083.jpg into Postgres
# ✅ Inserted frame_L26_V002_84 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/084.jpg into Postgres
# ✅ Inserted frame_L26_V002_85 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/085.jpg into Postgres
# ✅ Inserted frame_L26_V002_86 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/086.jpg into Postgres
# ✅ Inserted frame_L26_V002_87 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/087.jpg into Postgres
# ✅ Inserted frame_L26_V002_88 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/088.jpg into Postgres
# ✅ Inserted frame_L26_V002_89 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/089.jpg into Postgres
# ✅ Inserted frame_L26_V002_90 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/090.jpg into Postgres
# ✅ Inserted frame_L26_V002_91 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/091.jpg into Postgres
# ✅ Inserted frame_L26_V002_92 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/092.jpg into Postgres
# ✅ Inserted frame_L26_V002_93 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/093.jpg into Postgres
# ✅ Inserted frame_L26_V002_94 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/094.jpg into Postgres
# ✅ Inserted frame_L26_V002_95 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/095.jpg into Postgres
# ✅ Inserted frame_L26_V002_96 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/096.jpg into Postgres
# ✅ Inserted frame_L26_V002_97 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/097.jpg into Postgres
# ✅ Inserted frame_L26_V002_98 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/098.jpg into Postgres
# ✅ Inserted frame_L26_V002_99 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/099.jpg into Postgres
# ✅ Inserted frame_L26_V002_100 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/100.jpg into Postgres
# ✅ Inserted frame_L26_V002_101 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/101.jpg into Postgres
# ✅ Inserted frame_L26_V002_102 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/102.jpg into Postgres
# ✅ Inserted frame_L26_V002_103 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/103.jpg into Postgres
# ✅ Inserted frame_L26_V002_104 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/104.jpg into Postgres
# ✅ Inserted frame_L26_V002_105 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/105.jpg into Postgres
# ✅ Inserted frame_L26_V002_106 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/106.jpg into Postgres
# ✅ Inserted frame_L26_V002_107 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/107.jpg into Postgres
# ✅ Inserted frame_L26_V002_108 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/108.jpg into Postgres
# ✅ Inserted frame_L26_V002_109 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/109.jpg into Postgres
# ✅ Inserted frame_L26_V002_110 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/110.jpg into Postgres
# ✅ Inserted frame_L26_V002_111 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/111.jpg into Postgres
# ✅ Inserted frame_L26_V002_112 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/112.jpg into Postgres
# ✅ Inserted frame_L26_V002_113 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/113.jpg into Postgres
# ✅ Inserted frame_L26_V002_114 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/114.jpg into Postgres
# ✅ Inserted frame_L26_V002_115 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/115.jpg into Postgres
# ✅ Inserted frame_L26_V002_116 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/116.jpg into Postgres
# ✅ Inserted frame_L26_V002_117 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/117.jpg into Postgres
# ✅ Inserted frame_L26_V002_118 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/118.jpg into Postgres
# ✅ Inserted frame_L26_V002_119 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/119.jpg into Postgres
# ✅ Inserted frame_L26_V002_120 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/120.jpg into Postgres
# ✅ Inserted frame_L26_V002_121 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/121.jpg into Postgres
# ✅ Inserted frame_L26_V002_122 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/122.jpg into Postgres
# ✅ Done indexing L26_V002
# 🎥 Indexing frames for L26_V003 (video_id=3)
# ✅ Inserted frame_L26_V003_1 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/001.jpg into Postgres
# ✅ Inserted frame_L26_V003_2 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/002.jpg into Postgres
# ✅ Inserted frame_L26_V003_3 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/003.jpg into Postgres
# ✅ Inserted frame_L26_V003_4 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/004.jpg into Postgres
# ✅ Inserted frame_L26_V003_5 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/005.jpg into Postgres
# ✅ Inserted frame_L26_V003_6 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/006.jpg into Postgres
# ✅ Inserted frame_L26_V003_7 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/007.jpg into Postgres
# ✅ Inserted frame_L26_V003_8 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/008.jpg into Postgres
# ✅ Inserted frame_L26_V003_9 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/009.jpg into Postgres
# ✅ Inserted frame_L26_V003_10 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/010.jpg into Postgres
# ✅ Inserted frame_L26_V003_11 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/011.jpg into Postgres
# ✅ Inserted frame_L26_V003_12 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/012.jpg into Postgres
# ✅ Inserted frame_L26_V003_13 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/013.jpg into Postgres
# ✅ Inserted frame_L26_V003_14 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/014.jpg into Postgres
# ✅ Inserted frame_L26_V003_15 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/015.jpg into Postgres
# ✅ Inserted frame_L26_V003_16 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/016.jpg into Postgres
# ✅ Inserted frame_L26_V003_17 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/017.jpg into Postgres
# ✅ Inserted frame_L26_V003_18 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/018.jpg into Postgres
# ✅ Inserted frame_L26_V003_19 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/019.jpg into Postgres
# ✅ Inserted frame_L26_V003_20 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/020.jpg into Postgres
# ✅ Inserted frame_L26_V003_21 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/021.jpg into Postgres
# ✅ Inserted frame_L26_V003_22 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/022.jpg into Postgres
# ✅ Inserted frame_L26_V003_23 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/023.jpg into Postgres
# ✅ Inserted frame_L26_V003_24 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/024.jpg into Postgres
# ✅ Inserted frame_L26_V003_25 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/025.jpg into Postgres
# ✅ Inserted frame_L26_V003_26 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/026.jpg into Postgres
# ✅ Inserted frame_L26_V003_27 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/027.jpg into Postgres
# ✅ Inserted frame_L26_V003_28 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/028.jpg into Postgres
# ✅ Inserted frame_L26_V003_29 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/029.jpg into Postgres
# ✅ Inserted frame_L26_V003_30 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/030.jpg into Postgres
# ✅ Inserted frame_L26_V003_31 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/031.jpg into Postgres
# ✅ Inserted frame_L26_V003_32 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/032.jpg into Postgres
# ✅ Inserted frame_L26_V003_33 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/033.jpg into Postgres
# ✅ Inserted frame_L26_V003_34 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/034.jpg into Postgres
# ✅ Inserted frame_L26_V003_35 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/035.jpg into Postgres
# ✅ Inserted frame_L26_V003_36 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/036.jpg into Postgres
# ✅ Inserted frame_L26_V003_37 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/037.jpg into Postgres
# ✅ Inserted frame_L26_V003_38 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/038.jpg into Postgres
# ✅ Inserted frame_L26_V003_39 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/039.jpg into Postgres
# ✅ Inserted frame_L26_V003_40 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/040.jpg into Postgres
# ✅ Inserted frame_L26_V003_41 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/041.jpg into Postgres
# ✅ Inserted frame_L26_V003_42 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/042.jpg into Postgres
# ✅ Inserted frame_L26_V003_43 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/043.jpg into Postgres
# ✅ Inserted frame_L26_V003_44 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/044.jpg into Postgres
# ✅ Inserted frame_L26_V003_45 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/045.jpg into Postgres
# ✅ Inserted frame_L26_V003_46 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/046.jpg into Postgres
# ✅ Inserted frame_L26_V003_47 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/047.jpg into Postgres
# ✅ Inserted frame_L26_V003_48 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/048.jpg into Postgres
# ✅ Inserted frame_L26_V003_49 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/049.jpg into Postgres
# ✅ Inserted frame_L26_V003_50 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/050.jpg into Postgres
# ✅ Inserted frame_L26_V003_51 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/051.jpg into Postgres
# ✅ Inserted frame_L26_V003_52 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/052.jpg into Postgres
# ✅ Inserted frame_L26_V003_53 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/053.jpg into Postgres
# ✅ Inserted frame_L26_V003_54 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/054.jpg into Postgres
# ✅ Inserted frame_L26_V003_55 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/055.jpg into Postgres
# ✅ Inserted frame_L26_V003_56 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/056.jpg into Postgres
# ✅ Inserted frame_L26_V003_57 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/057.jpg into Postgres
# ✅ Inserted frame_L26_V003_58 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/058.jpg into Postgres
# ✅ Inserted frame_L26_V003_59 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/059.jpg into Postgres
# ✅ Inserted frame_L26_V003_60 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/060.jpg into Postgres
# ✅ Inserted frame_L26_V003_61 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/061.jpg into Postgres
# ✅ Inserted frame_L26_V003_62 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/062.jpg into Postgres
# ✅ Inserted frame_L26_V003_63 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/063.jpg into Postgres
# ✅ Inserted frame_L26_V003_64 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/064.jpg into Postgres
# ✅ Inserted frame_L26_V003_65 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/065.jpg into Postgres
# ✅ Inserted frame_L26_V003_66 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/066.jpg into Postgres
# ✅ Inserted frame_L26_V003_67 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/067.jpg into Postgres
# ✅ Inserted frame_L26_V003_68 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/068.jpg into Postgres
# ✅ Inserted frame_L26_V003_69 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/069.jpg into Postgres
# ✅ Inserted frame_L26_V003_70 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/070.jpg into Postgres
# ✅ Inserted frame_L26_V003_71 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/071.jpg into Postgres
# ✅ Inserted frame_L26_V003_72 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/072.jpg into Postgres
# ✅ Inserted frame_L26_V003_73 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/073.jpg into Postgres
# ✅ Inserted frame_L26_V003_74 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/074.jpg into Postgres
# ✅ Inserted frame_L26_V003_75 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/075.jpg into Postgres
# ✅ Inserted frame_L26_V003_76 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/076.jpg into Postgres
# ✅ Inserted frame_L26_V003_77 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/077.jpg into Postgres
# ✅ Inserted frame_L26_V003_78 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/078.jpg into Postgres
# ✅ Inserted frame_L26_V003_79 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/079.jpg into Postgres
# ✅ Inserted frame_L26_V003_80 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/080.jpg into Postgres
# ✅ Inserted frame_L26_V003_81 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/081.jpg into Postgres
# ✅ Inserted frame_L26_V003_82 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/082.jpg into Postgres
# ✅ Inserted frame_L26_V003_83 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/083.jpg into Postgres
# ✅ Inserted frame_L26_V003_84 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/084.jpg into Postgres
# ✅ Inserted frame_L26_V003_85 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/085.jpg into Postgres
# ✅ Inserted frame_L26_V003_86 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/086.jpg into Postgres
# ✅ Inserted frame_L26_V003_87 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/087.jpg into Postgres
# ✅ Inserted frame_L26_V003_88 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/088.jpg into Postgres
# ✅ Inserted frame_L26_V003_89 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/089.jpg into Postgres
# ✅ Inserted frame_L26_V003_90 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/090.jpg into Postgres
# ✅ Inserted frame_L26_V003_91 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/091.jpg into Postgres
# ✅ Inserted frame_L26_V003_92 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/092.jpg into Postgres
# ✅ Inserted frame_L26_V003_93 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/093.jpg into Postgres
# ✅ Inserted frame_L26_V003_94 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/094.jpg into Postgres
# ✅ Inserted frame_L26_V003_95 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/095.jpg into Postgres
# ✅ Inserted frame_L26_V003_96 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/096.jpg into Postgres
# ✅ Inserted frame_L26_V003_97 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/097.jpg into Postgres
# ✅ Inserted frame_L26_V003_98 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/098.jpg into Postgres
# ✅ Inserted frame_L26_V003_99 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/099.jpg into Postgres
# ✅ Inserted frame_L26_V003_100 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/100.jpg into Postgres
# ✅ Inserted frame_L26_V003_101 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/101.jpg into Postgres
# ✅ Inserted frame_L26_V003_102 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/102.jpg into Postgres
# ✅ Inserted frame_L26_V003_103 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/103.jpg into Postgres
# ✅ Inserted frame_L26_V003_104 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/104.jpg into Postgres
# ✅ Inserted frame_L26_V003_105 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/105.jpg into Postgres
# ✅ Inserted frame_L26_V003_106 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/106.jpg into Postgres
# ✅ Inserted frame_L26_V003_107 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/107.jpg into Postgres
# ✅ Inserted frame_L26_V003_108 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/108.jpg into Postgres
# ✅ Inserted frame_L26_V003_109 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/109.jpg into Postgres
# ✅ Inserted frame_L26_V003_110 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/110.jpg into Postgres
# ✅ Inserted frame_L26_V003_111 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/111.jpg into Postgres
# ✅ Inserted frame_L26_V003_112 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/112.jpg into Postgres
# ✅ Inserted frame_L26_V003_113 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/113.jpg into Postgres
# ✅ Inserted frame_L26_V003_114 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/114.jpg into Postgres
# ✅ Inserted frame_L26_V003_115 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/115.jpg into Postgres
# ✅ Inserted frame_L26_V003_116 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/116.jpg into Postgres
# ✅ Inserted frame_L26_V003_117 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/117.jpg into Postgres
# ✅ Inserted frame_L26_V003_118 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/118.jpg into Postgres
# ✅ Inserted frame_L26_V003_119 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/119.jpg into Postgres
# ✅ Inserted frame_L26_V003_120 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/120.jpg into Postgres
# ✅ Inserted frame_L26_V003_121 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/121.jpg into Postgres
# ✅ Inserted frame_L26_V003_122 into Milvus
# ✅ Inserted D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/122.jpg into Postgres
# ✅ Done indexing L26_V003

# %% [markdown]
# # Cell 6: Search Pipeline

# %%
import os
import pandas as pd
from deep_translator import GoogleTranslator
# === Hàm hỗ trợ ===
def format_time(seconds):
    m = int(seconds // 60)
    s = int(seconds % 60)
    return f"{m}:{s:02d}"

def group_timestamps(timestamps, gap_threshold=15.0):
    if not timestamps:
        return []
    timestamps = sorted(timestamps)
    ranges = []
    start = timestamps[0]
    end = timestamps[0]
    for t in timestamps[1:]:
        if t - end <= gap_threshold:
            end = t
        else:
            ranges.append((start, end))
            start = t
            end = t
    ranges.append((start, end))
    return ranges

def get_frame_idx_from_time(video_path, time_start, time_end, csv_dir):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    csv_path = os.path.join(csv_dir, f"{video_name}.csv")
    if not os.path.exists(csv_path):
        return None
    try:
        df = pd.read_csv(csv_path)
        if not all(col in df.columns for col in ['pts_time', 'frame_idx']):
            return None
        start_sec = int(time_start.split(":")[0]) * 60 + int(time_start.split(":")[1])
        end_sec = int(time_end.split(":")[0]) * 60 + int(time_end.split(":")[1])
        target_time = (start_sec + end_sec) / 2
        df['time_diff'] = abs(df['pts_time'] - target_time)
        closest_row = df.loc[df['time_diff'].idxmin()]
        return int(closest_row['frame_idx'])
    except:
        return None

def keyframe_path_from_frame_idx(video_path, frame_idx, csv_dir, frame_root):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    csv_path = os.path.join(csv_dir, f"{video_name}.csv")
    dir_path = os.path.join(frame_root, video_name)

    if not os.path.exists(csv_path):
        return None

    try:
        df = pd.read_csv(csv_path)
        if not all(c in df.columns for c in ["n", "frame_idx"]):
            return None

        # Tìm giá trị gần nhất của frame_idx
        idx = (df["frame_idx"] - int(frame_idx)).abs().idxmin()
        n_val = int(df.loc[idx, "n"])

        # Tạo danh sách tên ảnh có thể có
        candidates = []
        for stem in [n_val, frame_idx, f"{n_val:03d}", f"{frame_idx:03d}", f"{n_val:04d}", f"{frame_idx:04d}"]:
            for ext in ("jpg", "jpeg", "png"):
                candidates.append(os.path.join(dir_path, f"{stem}.{ext}"))

        for p in candidates:
            if os.path.exists(p):
                return p
    except Exception as e:
        print(f"❌ Lỗi đọc CSV hoặc tìm ảnh: {e}")
        return None

    return None


# === Hàm chính ===
def search_videos_by_text(text_query, top_k=20, gap_threshold=15.0):
    text_en = GoogleTranslator(source='vi', target='en').translate(text_query)

    dense_emb = clip_embedding._get_query_embedding(text_en)

    results = milvus_client.search(
        collection_name=COLLECTION_NAME,
        data=[dense_emb],
        limit=top_k,
        output_fields=["frame_path", "video_id"]
    )

    frame_paths = []
    video_ids = set()
    for hit in results[0]:
        entity = hit["entity"]
        frame_path = entity.get("frame_path")
        video_id = entity.get("video_id")
        if frame_path:
            frame_paths.append(frame_path)
        video_ids.add(video_id)

    output = []
    if frame_paths:
        cur.execute(f"""
            SELECT v.video_path, v.title, fm.pts_time, fm.frame_path
            FROM frame_mappings fm
            JOIN videos v ON fm.video_id = v.id
            WHERE fm.frame_path = ANY(%s)
        """, (frame_paths,))
        output.extend(cur.fetchall())

    for vid in video_ids:
        cur.execute("""
            SELECT video_path, title, NULL, NULL
            FROM videos
            WHERE video_path LIKE %s
        """, (f"%{vid}%",))
        row = cur.fetchone()
        if row:
            output.append(row)

    grouped_results = {}
    for video_path, title, pts_time, frame_path in output:
        if video_path not in grouped_results:
            grouped_results[video_path] = {"title": title, "timestamps": [], "frames": []}
        if pts_time is not None:
            grouped_results[video_path]["timestamps"].append((pts_time, frame_path))

    final_results = []
    for video_path, data in grouped_results.items():
        time_groups = group_timestamps([t[0] for t in data["timestamps"]], gap_threshold)
        ranges = []
        for start, end in time_groups:
            ranges.append((format_time(start), format_time(end)))
        final_results.append({
            "video_path": video_path,
            "title": data["title"],
            "time_ranges": ranges
        })

    return final_results

def format_search_results(search_results, csv_dir):
    grouped_results = {}
    for res in search_results:
        video_path = res['video_path']
        video_name = os.path.splitext(os.path.basename(video_path))[0]
        if video_path not in grouped_results:
            grouped_results[video_path] = (video_name, [])

        for time_start, time_end in res['time_ranges']:
            frame_idx = get_frame_idx_from_time(video_path, time_start, time_end, csv_dir)
            if frame_idx is not None:
                grouped_results[video_path][1].append((frame_idx, time_start, time_end))

    return grouped_results

# %%
# === Chạy demo ===
if __name__ == "__main__":
    text_vi = "ếch"
    search_results = search_videos_by_text(text_vi, top_k=20, gap_threshold=15.0)
    results = format_search_results(search_results, csv_dir=CSV_DIR)

    print(f"\nKết quả tìm kiếm cho: \"{text_vi}\"")
    for video_path, (video_name, frames) in results.items():
        print(f"\nVideo: {video_name}")
        print(f"Path: {video_path}")
        for frame_idx, time_start, time_end in frames:
            img_path = keyframe_path_from_frame_idx(
                video_path=video_path,
                frame_idx=frame_idx,
                csv_dir=CSV_DIR,
                frame_root=FRAME_DIR
            )
            img_path_str = img_path if img_path else "⚠️ Không tìm thấy ảnh"
            print(f"Frame Idx: {frame_idx} -- Xuất hiện từ {time_start} đến {time_end} -- Path: {img_path_str}")
# Out:
# Kết quả tìm kiếm cho: "ếch"
#
# Video: L26_V001
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V001.mp4
# Frame Idx: 224 -- Xuất hiện từ 0:08 đến 0:08 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V001\009.jpg
# Frame Idx: 1929 -- Xuất hiện từ 1:14 đến 1:20 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V001\035.jpg
# Frame Idx: 2716 -- Xuất hiện từ 1:41 đến 1:58 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V001\054.jpg
# Frame Idx: 4050 -- Xuất hiện từ 2:42 đến 2:42 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V001\077.jpg
# Frame Idx: 5199 -- Xuất hiện từ 3:27 đến 3:27 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V001\096.jpg
#
# Video: L26_V002
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V002.mp4
# Frame Idx: 135 -- Xuất hiện từ 0:03 đến 0:08 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\006.jpg
# Frame Idx: 1968 -- Xuất hiện từ 1:18 đến 1:18 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\035.jpg
# Frame Idx: 2348 -- Xuất hiện từ 1:33 đến 1:33 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\043.jpg
# Frame Idx: 3094 -- Xuất hiện từ 2:03 đến 2:03 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\055.jpg
# Frame Idx: 4119 -- Xuất hiện từ 2:44 đến 2:44 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\074.jpg
# Frame Idx: 5265 -- Xuất hiện từ 3:23 đến 3:37 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V002\093.jpg
#
# Video: L26_V003
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V003.mp4
# Frame Idx: 224 -- Xuất hiện từ 0:08 đến 0:08 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V003\009.jpg
# Frame Idx: 4028 -- Xuất hiện từ 2:41 đến 2:41 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V003\075.jpg
# Frame Idx: 4725 -- Xuất hiện từ 3:09 đến 3:09 -- Path: D:\Big_project_2025\Video_Similarity_Search\data_hybrid\keyframes\L26_V003\088.jpg

# %% [markdown]
# # ê

# %%
from deep_translator import GoogleTranslator
from pymilvus import Collection

# =========================
# Hàm dịch tiếng Việt -> Anh
# =========================
def preprocess_text(text, src="vi", tgt="en"):
    try:
        return GoogleTranslator(source=src, target=tgt).translate(text)
    except Exception as e:
        print(f"❌ Translate error: {e}")
        return text

# =========================
# Hàm tìm kiếm hybrid
# =========================
def search_videos_hybrid(query_text, top_k=10):
    """
    Tìm kiếm hybrid (CLIP + BM25) trong Milvus + Postgres
    Format output gọn đẹp, gom theo video
    """
    try:
        # Dịch query sang tiếng Anh cho CLIP
        query_text_en = preprocess_text(query_text, src="vi", tgt="en")

        # Encode query
        dense_emb = clip_embedding._get_text_embedding(query_text_en)

        # Chuẩn bị collection
        collection = Collection(COLLECTION_NAME)
        collection.load()

        # Search vector
        results = collection.search(
            data=[dense_emb],
            anns_field="vector",
            param={"metric_type": "IP", "params": {"ef": 64}},
            limit=top_k,
            output_fields=["frame_path", "video_id"]
        )

        # Gom kết quả
        output = {}
        for hit in results[0]:
            frame_path = hit.entity.get("frame_path", "")
            video_id = hit.entity.get("video_id", "")

            # Nếu là metadata (không phải frame) thì bỏ qua
            if not frame_path:
                continue

            # Frame index
            try:
                frame_idx = int(os.path.splitext(os.path.basename(frame_path))[0])
            except:
                frame_idx = -1

            # Lấy pts_time từ Postgres
            cur.execute("""
                SELECT v.video_path, f.pts_time, f.fps
                FROM frame_mappings f
                JOIN videos v ON f.video_id = v.id
                WHERE f.frame_path = %s
            """, (frame_path,))
            row = cur.fetchone()
            if not row:
                continue

            video_path, pts_time, fps = row

            # Gom theo video
            if video_id not in output:
                output[video_id] = {
                    "video_path": video_path,
                    "frames": []
                }

            time_str = format_time(pts_time)
            output[video_id]["frames"].append({
                "frame_idx": frame_idx,
                "time_start": time_str,
                "time_end": time_str,
                "frame_path": frame_path
            })

        # In kết quả
        print(f'Kết quả tìm kiếm cho: "{query_text}"\n')
        for video, data in output.items():
            print(f"Video: {video}")
            print(f"Path: {data['video_path']}")
            for f in data["frames"]:
                print(f"Frame Idx: {f['frame_idx']} -- Xuất hiện từ {f['time_start']} đến {f['time_end']} -- Path: {f['frame_path']}")
            print()

        return output

    except Exception as e:
        print(f"❌ Search error: {e}")
        return {}

# %%
search_videos_hybrid("thịt gà", top_k=10)
# Out:
# Kết quả tìm kiếm cho: "thịt gà"
#
# Video: L26_V001
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V001.mp4
# Frame Idx: 37 -- Xuất hiện từ 1:20 đến 1:20 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/037.jpg
# Frame Idx: 112 -- Xuất hiện từ 4:03 đến 4:03 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/112.jpg
# Frame Idx: 96 -- Xuất hiện từ 3:27 đến 3:27 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/096.jpg
# Frame Idx: 9 -- Xuất hiện từ 0:08 đến 0:08 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/009.jpg
#
# Video: L26_V002
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V002.mp4
# Frame Idx: 95 -- Xuất hiện từ 3:37 đến 3:37 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/095.jpg
# Frame Idx: 9 -- Xuất hiện từ 0:08 đến 0:08 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/009.jpg
# Frame Idx: 74 -- Xuất hiện từ 2:44 đến 2:44 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/074.jpg
#
# Video: L26_V003
# Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V003.mp4
# Frame Idx: 75 -- Xuất hiện từ 2:41 đến 2:41 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/075.jpg
# Frame Idx: 89 -- Xuất hiện từ 3:09 đến 3:09 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/089.jpg
# Frame Idx: 59 -- Xuất hiện từ 2:04 đến 2:04 -- Path: D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/059.jpg
# {'L26_V001': {'video_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V001.mp4',
#   'frames': [{'frame_idx': 37,
#     'time_start': '1:20',
#     'time_end': '1:20',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/037.jpg'},
#    {'frame_idx': 112,
#     'time_start': '4:03',
#     'time_end': '4:03',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/112.jpg'},
#    {'frame_idx': 96,
#     'time_start': '3:27',
#     'time_end': '3:27',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/096.jpg'},
#    {'frame_idx': 9,
#     'time_start': '0:08',
#     'time_end': '0:08',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V001/009.jpg'}]},
#  'L26_V002': {'video_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V002.mp4',
#   'frames': [{'frame_idx': 95,
#     'time_start': '3:37',
#     'time_end': '3:37',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/095.jpg'},
#    {'frame_idx': 9,
#     'time_start': '0:08',
#     'time_end': '0:08',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/009.jpg'},
#    {'frame_idx': 74,
#     'time_start': '2:44',
#     'time_end': '2:44',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V002/074.jpg'}]},
#  'L26_V003': {'video_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/video/L26_V003.mp4',
#   'frames': [{'frame_idx': 75,
#     'time_start': '2:41',
#     'time_end': '2:41',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/075.jpg'},
#    {'frame_idx': 89,
#     'time_start': '3:09',
#     'time_end': '3:09',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/089.jpg'},
#    {'frame_idx': 59,
#     'time_start': '2:04',
#     'time_end': '2:04',
#     'frame_path': 'D:/Big_project_2025/Video_Similarity_Search/data_hybrid/keyframes/L26_V003/059.jpg'}]}}
